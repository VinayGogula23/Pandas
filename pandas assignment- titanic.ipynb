# %%
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\Gogula Vinay\\Desktop\\Innomatics labs\\Data Science\\Saxson sir\\titanic.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## From the data frame access all the rows where sex will be mail

# %%
data.loc[data['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ## Try to count how many males and Females are there

# %%
print('total number of males are', len(data.loc[data['Sex']=='male']))
# Out:
# total number of males are 577

# %%
print('total number of females are',len(data.loc[data['Sex']=='female']))
# Out:
# total number of females are 314

# %%
## conver 1 to c1, 2 to c2 and 3 to c3, from pclass

# %%
data.loc[data['Pclass']==1,['Pclass']]=['class1']
data.loc[data['Pclass']==2,['Pclass']]=['class2']
data.loc[data['Pclass']==3,['Pclass']]=['class3']

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0  class3
# 1              2         1  class1
# 2              3         1  class3
# 3              4         1  class1
# 4              5         0  class3
# ..           ...       ...     ...
# 886          887         0  class2
# 887          888         1  class1
# 888          889         0  class3
# 889          890         1  class1
# 890          891         0  class3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0  class3
# 1              2         1  class1
# 2              3         1  class3
# 3              4         1  class1
# 4              5         0  class3
# ..           ...       ...     ...
# 886          887         0  class2
# 887          888         1  class1
# 888          889         0  class3
# 889          890         1  class1
# 890          891         0  class3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## from the data frame print the males whose age is in b/w  35 to 55.

# %%
a=data.loc[((data['Age']>=35) & (data['Age']<=55))]
a.loc[a['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 4              5         0  class3     Allen, Mr. William Henry  male  35.0
# 6              7         0  class1      McCarthy, Mr. Timothy J  male  54.0
# 13            14         0  class3  Andersson, Mr. Anders Johan  male  39.0
# 20            21         0  class2         Fynney, Mr. Joseph J  male  35.0
# 30            31         0  class1     Uruchurtu, Don. Manuel E  male  40.0
# ..           ...       ...     ...                          ...   ...   ...
# 845          846         0  class3          Abbing, Mr. Anthony  male  42.0
# 847          848         0  class3           Markoff, Mr. Marin  male  35.0
# 857          858         1  class1       Daly, Mr. Peter Denis   male  51.0
# 860          861         0  class3      Hansen, Mr. Claus Peter  male  41.0
# 873          874         0  class3  Vander Cruyssen, Mr. Victor  male  47.0
#
#      SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %%
data.loc[(data['Sex']=='male') & (data['Age']>35) & (data['Age']<=55)]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 6              7         0  class1          McCarthy, Mr. Timothy J  male
# 13            14         0  class3      Andersson, Mr. Anders Johan  male
# 30            31         0  class1         Uruchurtu, Don. Manuel E  male
# 35            36         0  class1   Holverson, Mr. Alexander Oskar  male
# 62            63         0  class1      Harris, Mr. Henry Birkhardt  male
# ..           ...       ...     ...                              ...   ...
# 822          823         0  class1  Reuchlin, Jonkheer. John George  male
# 845          846         0  class3              Abbing, Mr. Anthony  male
# 857          858         1  class1           Daly, Mr. Peter Denis   male
# 860          861         0  class3          Hansen, Mr. Claus Peter  male
# 873          874         0  class3      Vander Cruyssen, Mr. Victor  male
#
#       Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ## print the names of male gender whos age is between 35 to 55

# %%
data.loc[(data['Sex']=='male') & (data['Age']>35) & (data['Age']<=55),['Name']]
# Out:
#                                 Name
# 6            McCarthy, Mr. Timothy J
# 13       Andersson, Mr. Anders Johan
# 30          Uruchurtu, Don. Manuel E
# 35    Holverson, Mr. Alexander Oskar
# 62       Harris, Mr. Henry Birkhardt
# ..                               ...
# 822  Reuchlin, Jonkheer. John George
# 845              Abbing, Mr. Anthony
# 857           Daly, Mr. Peter Denis
# 860          Hansen, Mr. Claus Peter
# 873      Vander Cruyssen, Mr. Victor
#
# [113 rows x 1 columns]

# %% [markdown]
# ## print the number of males present in age gap of 35 to 55

# %%
print('the number of male persons from age gap 35 to 55: ',len(data.loc[(data['Sex']=='male') & (data['Age']>35) & (data['Age']<=55)]))
# Out:
# the number of male persons from age gap 35 to 55:  113

# %% [markdown]
# ## print the number of males present in age gap of 35 to 55

# %%
print('the number of male persons from age gap 35 to 55: ',len(data.loc[(data['Sex']=='female') & (data['Age']>35) & (data['Age']<=55)]))
# Out:
# the number of male persons from age gap 35 to 55:  64

# %% [markdown]
# ## count how many persons are ther in pclass 3

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0  class3
# 1              2         1  class1
# 2              3         1  class3
# 3              4         1  class1
# 4              5         0  class3
# ..           ...       ...     ...
# 886          887         0  class2
# 887          888         1  class1
# 888          889         0  class3
# 889          890         1  class1
# 890          891         0  class3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print('the total number of students present in class 3 are: ',len(data.loc[data['Pclass']=='class3']))
# Out:
# the total number of students present in class 3 are:  491

# %% [markdown]
# ## from Embarked find the unic values

# %%
set(data['Embarked'])
# Out:
# {'C', 'Q', 'S', nan}
