# %%
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\saxon\\Desktop\\Code\\DataSet\\titanic.csv",usecols=["PassengerId","Survived","Pclass"])

# %%
data
# Out:
#                a         b       c  \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                      d
# 0                                                 Name
# 1                              Braund, Mr. Owen Harris
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                               Heikkinen, Miss. Laina
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ..                                                 ...
# 887                              Montvila, Rev. Juozas
# 888                       Graham, Miss. Margaret Edith
# ...

# %%
pd.read_csv("C:\\Users\\saxon\\Desktop\\Code\\DataSet\\A1.csv",names=["a","b","c"])
# Out:
#     a
# 0  p7
# 1  p1
# 2  p3
# 3  p4
# 4  p5
# 5  p6
# 6  p7
# 7  p8

# %%
pd.read_csv("C:\\Users\\saxon\\Desktop\\Code\\DataSet\\A1.csv",nrows=2,header=None)
# Out:
#     0   1  2
# 0  p7   2  m
# 1  p1  22  m

# %%
pd.read_csv("C:\\Users\\saxon\\Desktop\\Code\\DataSet\\A1.csv",header=None)
# Out:
#     0   1  2
# 0  p7   2  m
# 1  p1  22  m
# 2  p3  24  F
# 3  p4  24  F
# 4  p5  24  M
# 5  p6  24  F
# 6  p7  24  M
# 7  p8  22  F

# %%
pd.read_csv("C:\\Users\\saxon\\Desktop\\Code\\DataSet\\A1.csv",header=None)
# Out:
#     0    1   2
# 0  p7    2   f
# 1  p1   22   m
# 2  p3   34   F
# 3  p4  -34  FD
# 4  p5   24   M
# 5  p6   24   F
# 6  p7 -213  34
# 7  p8   22   F

# %%
pd.read_csv("C:\\Users\\saxon\\Desktop\\Code\\DataSet\\A1.csv",header=None,na_values=[-213,-34,"FD",34])
# Out:
#     0     1    2
# 0  p7   2.0    f
# 1  p1  22.0    m
# 2  p3   NaN    F
# 3  p4   NaN  NaN
# 4  p5  24.0    M
# 5  p6  24.0    F
# 6  p7   NaN  NaN
# 7  p8  22.0    F

# %%
pd.read_csv("C:\\Users\\saxon\\Desktop\\Code\\DataSet\\A1.csv",header=None)
# Out:
#     0    1   2
# 0  p7    2   f
# 1  p1   22   m
# 2  p3   34   F
# 3  p4  -34  FD
# 4  p5   24   M
# 5  p6   24   F
# 6  p7 -213  34
# 7  p8   22   F

# %%
pd.read_csv("C:\\Users\\saxon\\Desktop\\Code\\DataSet\\A1.csv",header=None,na_values={1:[-34,-213],2:["FD",34]})
# Out:
#     0     1    2
# 0  p7   2.0    f
# 1  p1  22.0    m
# 2  p3  34.0    F
# 3  p4   NaN  NaN
# 4  p5  24.0    M
# 5  p6  24.0    F
# 6  p7   NaN  NaN
# 7  p8  22.0    F

# %%
pd.read_csv("C:\\Users\\saxon\\Desktop\\Code\\DataSet\\A1.csv",header=None)
# Out:
#     0    1    2
# 0  p7    2    f
# 1  p1   22    m
# 2  p3   34  NaN
# 3  p4  -34   FD
# 4  p5   24    M
# 5  p6   24    F
# 6  p7 -213   34
# 7  p8   22    F
