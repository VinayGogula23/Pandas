# %%
import pandas as pd
import numpy as np
data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %% [markdown]
# ####Write a Pandas program to create a dataframe by given dictionary and index as lables

# %%
import pandas as pd
import numpy as np
data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
game=pd.DataFrame(data,index=labels)
game
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# ##### 1. Write a Pandas program to select the rows where the score is missing, i.e. is NaN

# %%
game=pd.DataFrame(data,index=labels)
game
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
game[game['score'].isnull()]
# Out:
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %% [markdown]
# ##### 2. Write a Pandas program to change the score in row 'd' to 11.5.

# %%
game.loc['d','score']=11.5
game
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# ##### 3. Write a Pandas program to select the 'name' and 'score' columns from the following DataFrame.

# %%
game=pd.DataFrame(data,index=labels,columns=['name','score'])
game
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %% [markdown]
# ##### 4.  Write a Pandas program to calculate the mean score for each different student in DataFrame.

# %%
game['score'].mean()
# Out:
# 13.5625

# %% [markdown]
# ##### 5. Write a Pandas program to append a new row 'k' to data frame with any value for each column. Now delete the row 'c' and return the original DataFrame.

# %%
game=pd.DataFrame(data,index=labels)
game
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
game.loc['k']={"name":'Ram',"score":100,"attempts":3,"qualify":'Yes'}
game
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k        Ram  100.0         3     Yes

# %%
game.drop('c')
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k        Ram  100.0         3     Yes

# %% [markdown]
# ###### import the titanic dataset

# %% [markdown]
# ##### 1. Write a Pandas program to create a Pivot table and find the total fare amount class wise, gender wise.

# %%
import pandas as pd
titanicdata=pd.read_csv(r"C:\Users\Gogula Vinay\Desktop\Innomatics labs\Data Science\lms assignment\9. Pandas\Pandas_assignment\Pandas_day_2\titanic.csv")
titanicdata
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
pd.pivot_table(titanicdata,index=['pclass','sex'],values='fare')
# Out:
#                      fare
# pclass sex
# 1      female  106.125798
#        male     67.226127
# 2      female   21.970121
#        male     19.741782
# 3      female   16.118810
#        male     12.661633

# %% [markdown]
# ##### 2. Write a Pandas program to create a Pivot table and find survival rate by gender.

# %%
g=titanicdata.groupby(['sex'])
g.ngroups
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# ...

# %%
pd.pivot_table(titanicdata,index=['sex'],values=['survived'])
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %% [markdown]
# ###### 3. Write a Pandas to create to find the total count no of people survived pclass wise, class wise and gender wise.

# %%
pd.pivot_table(titanicdata,index=['pclass','class','sex'],values=['survived'])
# Out:
#                       survived
# pclass class  sex
# 1      First  female  0.968085
#               male    0.368852
# 2      Second female  0.921053
#               male    0.157407
# 3      Third  female  0.500000
#               male    0.135447

# %% [markdown]
# ###### 4. Write a Pandas program to create a Pivot table and calculate how many women and men were in a particular cabin class.

# %%
import numpy as np
pd.pivot_table(titanicdataa,index=['class','sex'],values=['pclass'],aggfunc='count')
# Out:
#                pclass
# class  sex
# First  female      94
#        male       122
# Second female      76
#        male       108
# Third  female     144
#        male       347

# %%
pd.pivot_table()aggfunc: 'AggFuncType' = 'mean'

# %% [markdown]
# ##### 5. Write a Pandas program to count the number of missing values in each column.

# %%
titanicdata=pd.read_csv("C:\\Users\\Gogula Vinay\\Desktop\\Innomatics labs\\Data Science\\lms assignment\\9. Pandas\\Pandas_assignment\\Pandas_day_2\\titanic.csv")
titanicdata.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# Unnamed: 15    891
# dtype: int64

# %% [markdown]
# ##### 6. Write a Pandas program to replace null values with the value from the previous row or the next row in a given DataFrame.

# %%
titanicdata=pd.read_csv("C:\\Users\\Gogula Vinay\\Desktop\\Innomatics labs\\Data Science\\lms assignment\\9. Pandas\\Pandas_assignment\\Pandas_day_2\\titanic.csv")
titanicdata
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
titanicdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  Unnamed: 15  0 non-null      float64
# dtypes: bool(2), float64(3), int64(4), object(7)
# memory usage: 99.3+ KB

# %%
titanicdata.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# Unnamed: 15    891
# dtype: int64

# %%
titdata=titanicdata.fillna(method='ffill')
titdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         890 non-null    object
#  12  embark_town  891 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  Unnamed: 15  0 non-null      float64
# dtypes: bool(2), float64(3), int64(4), object(7)
# memory usage: 99.3+ KB

# %%
titdata.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck             1
# embark_town      0
# alive            0
# alone            0
# Unnamed: 15    891
# dtype: int64

# %% [markdown]
# ###### 7. Write a Pandas program to replace nulls, with median or mean of the specified columns in a given DataFrame.

# %%
titanicdataa=pd.read_csv("C:\\Users\\Gogula Vinay\\Desktop\\Innomatics labs\\Data Science\\lms assignment\\9. Pandas\\Pandas_assignment\\Pandas_day_2\\titanic.csv")
titanicdataa
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
titanicdataa.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# Unnamed: 15    891
# dtype: int64

# %%
titanicdataa.fillna({'age':titanicdataa['age'].mean(),'deck':titanicdataa['deck'].mode()[0],'embarked':titanicdataa['embarked'].mode()[0],'embark_town':titanicdataa['embark_town'].mode()[0]},inplace=True)

# %%
titanicdataa.isnull().sum() # error cmg....
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck             0
# embark_town      0
# alive            0
# alone            0
# Unnamed: 15    891
# dtype: int64

# %% [markdown]
# ###### 8. Write a Pandas program to select first 2 rows, 2 columns and specific two columns from the dataframe.

# %%
titanicdata
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# ###### 9. Write a Pandas program to remove the duplicates from 'embark_town' column of titanic dataset.

# %%
titanicdata
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
titanicdata['embarked']

# %%
titanicdata['embarked'].drop_duplicates(keep=False)
# Out:
# Series([], Name: embarked, dtype: object)

# %%
titanicdata['embarked']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# ###### 10. Write a Pandas program to find out the survived is 1 details by the 'Southampton' in who is the 'child' from dataset.

# %%
titanicdata.loc[(titanicdata['survived']==1) & (titanicdata['embark_town']=='Southampton')]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 865         1       2  female  42.0      0      0  13.0000        S  Second
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
# ...

# %% [markdown]
# ###### 11. Write a Pandas program to filter all records starting from the 2nd row, access every 5th row from the dataframe.

# %%
import pandas as pd

# %%
titanicdat11=pd.read_csv("C:\\Users\\Gogula Vinay\\Desktop\\Innomatics labs\\Data Science\\lms assignment\\9. Pandas\\Pandas_assignment\\Pandas_day_2\\titanic.csv",names=['survived','pclass','sex','age','sibsp','parch','fare','embarked','class','who','adult_male','deck','embark_town','alive','alone'],skiprows=[0,1,2])
titanicdat11
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           1       3  female  26.0      0      0   7.9250        S   Third
# 1           1       1  female  35.0      1      0  53.1000        S   First
# 2           0       3    male  35.0      0      0   8.0500        S   Third
# 3           0       3    male   NaN      0      0   8.4583        Q   Third
# 4           0       1    male  54.0      0      0  51.8625        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       2    male  27.0      0      0  13.0000        S  Second
# 885         1       1  female  19.0      0      0  30.0000        S   First
# 886         0       3  female   NaN      1      2  23.4500        S   Third
# 887         1       1    male  26.0      0      0  30.0000        C   First
# 888         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanicdat11.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         1       3  female  26.0      0      0   7.9250        S   Third
# 1         1       1  female  35.0      1      0  53.1000        S   First
# 2         0       3    male  35.0      0      0   8.0500        S   Third
# 3         0       3    male   NaN      0      0   8.4583        Q   Third
# 4         0       1    male  54.0      0      0  51.8625        S   First
# 5         0       3    male   2.0      3      1  21.0750        S   Third
# 6         1       3  female  27.0      0      2  11.1333        S   Third
# 7         1       2  female  14.0      1      0  30.0708        C  Second
# 8         1       3  female   4.0      1      1  16.7000        S   Third
# 9         1       1  female  58.0      0      0  26.5500        S   First
#
#      who  adult_male deck  embark_town alive  alone
# 0  woman       False  NaN  Southampton   yes   True
# ...

# %%
titanicdat11.loc[0::5]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           1       3  female  26.0      0      0   7.9250        S   Third
# 5           0       3    male   2.0      3      1  21.0750        S   Third
# 10          0       3    male  20.0      0      0   8.0500        S   Third
# 15          1       2    male   NaN      0      0  13.0000        S  Second
# 20          1       3  female  15.0      0      0   8.0292        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 865         0       1    male  31.0      0      0  50.4958        S   First
# 870         0       1    male  33.0      0      0   5.0000        S   First
# 875         0       3    male  19.0      0      0   7.8958        S   Third
# 880         0       3  female  22.0      0      0  10.5167        S   Third
# 885         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ###### 12. Write a Pandas program to filter those records where embarked matches with multiple values (C, Q) from the dataset.

# %%
titanicdata
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
titanicdata.loc[(titanicdata['embarked']=='C') | (titanicdata['embarked']=='Q')]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# 19          1       3  female   NaN      0      0   7.2250        C   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...
